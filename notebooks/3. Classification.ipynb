# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import numpy as np
import inputs2, classification
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %% [markdown]
# #### Select the parameters and models for training, validation and testing

# %%
task_input_list = [
    inputs2.load_binary, 
    inputs2.load_six_transients, 
    inputs2.load_seven_transients,
    inputs2.load_seven_classes,
    inputs2.load_eight_classes
]
num_obs_list = [
    5,
    10
]
num_features_list = [
    20,
    26,
    30, 
]
oversample_list = [
    False,
    True, 
]
model_list = [
    classification.svc,
    classification.rf,
    classification.mlp
]
scaler_list = [
    StandardScaler,            
    MinMaxScaler
]

# %% [markdown]
# #### For every combination of parameters selected, perform classification

# %%
results = classification.run_tasks(
    task_input_list, 
    num_obs_list, num_features_list, oversample_list, model_list, scaler_list
)
# Out:
# Starting: binary, 5, 20, False, svc, StandardScaler
# Finished combination
# Starting: binary, 5, 20, False, svc, MinMaxScaler
# Finished combination
# Starting: binary, 5, 20, False, rf, StandardScaler
# Finished combination
# Starting: binary, 5, 20, False, rf, MinMaxScaler
# Finished combination
# Starting: binary, 5, 20, False, mlp, StandardScaler
# Finished combination
# Starting: binary, 5, 20, False, mlp, MinMaxScaler
# Finished combination
# Starting: binary, 5, 26, False, svc, StandardScaler
# Finished combination
# Starting: binary, 5, 26, False, svc, MinMaxScaler
# Finished combination
# Starting: binary, 5, 26, False, rf, StandardScaler
# Finished combination
# Starting: binary, 5, 26, False, rf, MinMaxScaler
# Finished combination
# Starting: binary, 5, 26, False, mlp, StandardScaler
# Finished combination
# Starting: binary, 5, 26, False, mlp, MinMaxScaler
# Finished combination
# Starting: binary, 5, 30, False, svc, StandardScaler
# Finished combination
# ...

# %%
# results[0]
